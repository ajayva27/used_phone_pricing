# %%
#import dataset
import pandas as pd
data=pd.read_csv(r"C:\Users\HP\Downloads\used_device_data.csv")
data
# Out:
#      device_brand       os  screen_size   4g   5g  rear_camera_mp  \
# 0           Honor  Android        14.50  yes   no            13.0
# 1           Honor  Android        17.30  yes  yes            13.0
# 2           Honor  Android        16.69  yes  yes            13.0
# 3           Honor  Android        25.50  yes  yes            13.0
# 4           Honor  Android        15.32  yes   no            13.0
# ...           ...      ...          ...  ...  ...             ...
# 3449         Asus  Android        15.34  yes   no             NaN
# 3450         Asus  Android        15.24  yes   no            13.0
# 3451      Alcatel  Android        15.80  yes   no            13.0
# 3452      Alcatel  Android        15.80  yes   no            13.0
# 3453      Alcatel  Android        12.83  yes   no            13.0
#
#       front_camera_mp  internal_memory  ram  battery  weight  release_year  \
# 0                 5.0             64.0  3.0   3020.0   146.0          2020
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3454 entries, 0 to 3453
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   device_brand           3454 non-null   object
#  1   os                     3454 non-null   object
#  2   screen_size            3454 non-null   float64
#  3   4g                     3454 non-null   object
#  4   5g                     3454 non-null   object
#  5   rear_camera_mp         3275 non-null   float64
#  6   front_camera_mp        3452 non-null   float64
#  7   internal_memory        3450 non-null   float64
#  8   ram                    3450 non-null   float64
#  9   battery                3448 non-null   float64
#  10  weight                 3447 non-null   float64
#  11  release_year           3454 non-null   int64
#  12  days_used              3454 non-null   int64
#  13  normalized_used_price  3454 non-null   float64
# ...

# %%
data.describe()
# Out:
#        screen_size  rear_camera_mp  front_camera_mp  internal_memory  \
# count  3454.000000     3275.000000      3452.000000      3450.000000
# mean     13.713115        9.460208         6.554229        54.573099
# std       3.805280        4.815461         6.970372        84.972371
# min       5.080000        0.080000         0.000000         0.010000
# 25%      12.700000        5.000000         2.000000        16.000000
# 50%      12.830000        8.000000         5.000000        32.000000
# 75%      15.340000       13.000000         8.000000        64.000000
# max      30.710000       48.000000        32.000000      1024.000000
#
#                ram      battery       weight  release_year    days_used  \
# count  3450.000000  3448.000000  3447.000000   3454.000000  3454.000000
# mean      4.036122  3133.402697   182.751871   2015.965258   674.869716
# std       1.365105  1299.682844    88.413228      2.298455   248.580166
# ...

# %%
data.describe(include='object')
# Out:
#        device_brand       os    4g    5g
# count          3454     3454  3454  3454
# unique           34        4     2     2
# top          Others  Android   yes    no
# freq            502     3214  2335  3302

# %%
#covert yes or no in 4g,5g to 1 and 0
data['4g']=data['4g'].replace(['yes','no'],[1,0])
data['5g']=data['5g'].replace(['yes','no'],[1,0])

# %%
# #convert price to INR by *90 (89.50)
# data['normalized_used_price']=data['normalized_used_price']*90
# data['normalized_new_price']=data['normalized_new_price']*90

# %%
# data['normalized_used_price']=data['normalized_used_price']*10
# data['normalized_new_price']=data['normalized_new_price']*10

# %%
# #round the decimal values
# import math
# data['normalized_used_price']=round(data['normalized_used_price'])
# data['normalized_new_price']=round(data['normalized_new_price'])

# %%
# import math
# data['normalized_used_price']=round(data['normalized_used_price'])
# data['normalized_new_price']=round(data['normalized_new_price'])

# %%
data.head()
# Out:
#   device_brand       os  screen_size  4g  5g  rear_camera_mp  front_camera_mp  \
# 0        Honor  Android        14.50   1   0            13.0              5.0
# 1        Honor  Android        17.30   1   1            13.0             16.0
# 2        Honor  Android        16.69   1   1            13.0              8.0
# 3        Honor  Android        25.50   1   1            13.0              8.0
# 4        Honor  Android        15.32   1   0            13.0              8.0
#
#    internal_memory  ram  battery  weight  release_year  days_used  \
# 0             64.0  3.0   3020.0   146.0          2020        127
# 1            128.0  8.0   4300.0   213.0          2020        325
# 2            128.0  8.0   4200.0   213.0          2020        162
# 3             64.0  6.0   7250.0   480.0          2020        345
# 4             64.0  3.0   5000.0   185.0          2020        293
#
#    normalized_used_price  normalized_new_price
# 0               4.307572              4.715100
# ...

# %%
data['device_brand'].unique()
# Out:
# array(['Honor', 'Others', 'HTC', 'Huawei', 'Infinix', 'Lava', 'Lenovo',
#        'LG', 'Meizu', 'Micromax', 'Motorola', 'Nokia', 'OnePlus', 'Oppo',
#        'Realme', 'Samsung', 'Vivo', 'Xiaomi', 'ZTE', 'Apple', 'Asus',
#        'Coolpad', 'Acer', 'Alcatel', 'BlackBerry', 'Celkon', 'Gionee',
#        'Google', 'Karbonn', 'Microsoft', 'Panasonic', 'Sony', 'Spice',
#        'XOLO'], dtype=object)

# %%
data['device_brand'].value_counts()
# Out:
# device_brand
# Others        502
# Samsung       341
# Huawei        251
# LG            201
# Lenovo        171
# ZTE           140
# Xiaomi        132
# Oppo          129
# Asus          122
# Alcatel       121
# Micromax      117
# Vivo          117
# Honor         116
# HTC           110
# Nokia         106
# Motorola      106
# Sony           86
# Meizu          62
# Gionee         56
# Acer           51
# XOLO           49
# Panasonic      47
# Realme         41
# Apple          39
# Lava           36
# Celkon         33
# Spice          30
# Karbonn        29
# Coolpad        22
# BlackBerry     22
# Microsoft      22
# OnePlus        22
# Google         15
# Infinix        10
# Name: count, dtype: int64

# %%
data['os'].value_counts()
# Out:
# os
# Android    3214
# Others      137
# Windows      67
# iOS          36
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['device_brand', 'os', 'screen_size', '4g', '5g', 'rear_camera_mp',
#        'front_camera_mp', 'internal_memory', 'ram', 'battery', 'weight',
#        'release_year', 'days_used', 'normalized_used_price',
#        'normalized_new_price'],
#       dtype='object')

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.scatter(data['normalized_new_price'],data['normalized_used_price'],color='red')
plt.title("used price vs new price")
plt.xlabel("New price")
plt.ylabel("Used Price")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.scatter(data['days_used'],data['normalized_used_price'],color='red')
plt.title("used price vs Days_used")
plt.xlabel("Days_used")
plt.ylabel("Used Price")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.scatter(data['release_year'],data['normalized_used_price'],color='red')
plt.title("used price vs release year")
plt.xlabel("Release year")
plt.ylabel("Used Price")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.scatter(data['weight'],data['normalized_used_price'],color='red')
plt.title("used price vs weight")
plt.xlabel("Weight")
plt.ylabel("Used Price")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.scatter(data['battery'],data['normalized_used_price'],color='red')
plt.title("used price vs battery")
plt.xlabel("battery")
plt.ylabel("Used Price")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.scatter(data['ram'],data['normalized_used_price'],color='red')
plt.title("used price vs ram")
plt.xlabel("Ram")
plt.ylabel("Used Price")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.scatter(data['internal_memory'],data['normalized_used_price'],color='red')
plt.title("used price vs internal_memory")
plt.xlabel("internal_memory")
plt.ylabel("Used Price")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.scatter(data['front_camera_mp'],data['normalized_used_price'],color='red')
plt.title("used price vs front_camera_mp")
plt.xlabel("front_camera_mp")
plt.ylabel("Used Price")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.scatter(data['rear_camera_mp'],data['normalized_used_price'],color='red')
plt.title("used price vs rear_camera_mp")
plt.xlabel("rear_camera_mp")
plt.ylabel("Used Price")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.scatter(data['screen_size'],data['normalized_used_price'],color='red')
plt.title("used price vs screen_size")
plt.xlabel("screen_size")
plt.ylabel("Used Price")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.scatter(data['normalized_used_price'],data['os'],color='red')
plt.title("used price vs OS")
plt.xlabel("Used price")
plt.ylabel("OS")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.scatter(data['normalized_used_price'],data['device_brand'],color='red')
plt.title("used price vs Brand name")
plt.xlabel("Used price")
plt.ylabel("Brand name")
plt.grid(True)
plt.show()

# %%
import seaborn as sns
# sns.pairplot(data,height=3,diag_kind='kde',corner=True)

# %%
sns.barplot(x=data['normalized_used_price'],
            y=data['device_brand'],
            ci=False,
            order=data.groupby('device_brand')['normalized_used_price'].mean().sort_values(ascending=False).index)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7356\1536824282.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x=data['normalized_used_price'],
# <Axes: xlabel='normalized_used_price', ylabel='device_brand'>

# %%
sns.barplot(x=data['normalized_used_price'],
            y=data['os'],
            ci=False,
            order=data.groupby('os')['normalized_used_price'].mean().sort_values(ascending=False).index)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7356\2288205792.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x=data['normalized_used_price'],
# <Axes: xlabel='normalized_used_price', ylabel='os'>

# %%
sns.barplot(x=data['4g'],
            y=data['normalized_used_price'],
            ci=False,
            order=data.groupby('4g')['normalized_used_price'].mean().sort_values(ascending=False).index)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7356\4225328679.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x=data['4g'],
# <Axes: xlabel='4g', ylabel='normalized_used_price'>

# %%
sns.barplot(x=data['5g'],
            y=data['normalized_used_price'],
            ci=False,
            order=data.groupby('5g')['normalized_used_price'].mean().sort_values(ascending=False).index)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7356\2058630613.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x=data['5g'],
# <Axes: xlabel='5g', ylabel='normalized_used_price'>

# %%
plt.figure(figsize=(20,10))
data_numeric = data.apply(pd.to_numeric, errors='coerce')
sns.heatmap(data_numeric.corr(),annot=True,fmt='.2f')
plt.show()

# %%
#prepration

# %%
data.isnull().sum()
# Out:
# device_brand               0
# os                         0
# screen_size                0
# 4g                         0
# 5g                         0
# rear_camera_mp           179
# front_camera_mp            2
# internal_memory            4
# ram                        4
# battery                    6
# weight                     7
# release_year               0
# days_used                  0
# normalized_used_price      0
# normalized_new_price       0
# dtype: int64

# %%
(data.isnull().sum()/data.shape[0]*100)[data.isnull().sum()>0]
# Out:
# rear_camera_mp     5.182397
# front_camera_mp    0.057904
# internal_memory    0.115808
# ram                0.115808
# battery            0.173712
# weight             0.202664
# dtype: float64

# %%
data.groupby(["device_brand"],as_index=False)['rear_camera_mp'].median()
# Out:
#    device_brand  rear_camera_mp
# 0          Acer            5.00
# 1       Alcatel            5.00
# 2         Apple           12.00
# 3          Asus           13.00
# 4    BlackBerry            8.00
# 5        Celkon            3.15
# 6       Coolpad           13.00
# 7        Gionee            8.00
# 8        Google           12.20
# 9           HTC           13.00
# 10        Honor           13.00
# 11       Huawei           13.00
# 12      Infinix             NaN
# 13      Karbonn            5.00
# 14           LG            8.00
# 15         Lava            8.00
# 16       Lenovo            8.00
# 17        Meizu           13.00
# 18     Micromax            5.00
# 19    Microsoft            8.00
# 20     Motorola           13.00
# 21        Nokia            5.00
# 22      OnePlus           13.00
# 23         Oppo           13.00
# 24       Others            8.00
# 25    Panasonic            8.00
# 26       Realme           13.00
# 27      Samsung            8.00
# ...

# %%
data['rear_camera_mp']=data.groupby(["device_brand"])['rear_camera_mp'].transform(
lambda x:x.fillna(x.median()))

# %%
data.isnull().sum()
# Out:
# device_brand              0
# os                        0
# screen_size               0
# 4g                        0
# 5g                        0
# rear_camera_mp           10
# front_camera_mp           2
# internal_memory           4
# ram                       4
# battery                   6
# weight                    7
# release_year              0
# days_used                 0
# normalized_used_price     0
# normalized_new_price      0
# dtype: int64

# %%
data=data.dropna()

# %%
# for i in data.columns:
#     if data[i].dtype!="object":
#         median=data[i].median()
#         data[i]=data[i].fillna(median)

# %%
data.isnull().sum()
# Out:
# device_brand             0
# os                       0
# screen_size              0
# 4g                       0
# 5g                       0
# rear_camera_mp           0
# front_camera_mp          0
# internal_memory          0
# ram                      0
# battery                  0
# weight                   0
# release_year             0
# days_used                0
# normalized_used_price    0
# normalized_new_price     0
# dtype: int64

# %%
x=data.drop('normalized_used_price',axis=1)
y=data[['normalized_used_price']]

# %%
x.head()
# Out:
#   device_brand       os  screen_size  4g  5g  rear_camera_mp  front_camera_mp  \
# 0        Honor  Android        14.50   1   0            13.0              5.0
# 1        Honor  Android        17.30   1   1            13.0             16.0
# 2        Honor  Android        16.69   1   1            13.0              8.0
# 3        Honor  Android        25.50   1   1            13.0              8.0
# 4        Honor  Android        15.32   1   0            13.0              8.0
#
#    internal_memory  ram  battery  weight  release_year  days_used  \
# 0             64.0  3.0   3020.0   146.0          2020        127
# 1            128.0  8.0   4300.0   213.0          2020        325
# 2            128.0  8.0   4200.0   213.0          2020        162
# 3             64.0  6.0   7250.0   480.0          2020        345
# 4             64.0  3.0   5000.0   185.0          2020        293
#
#    normalized_new_price
# 0              4.715100
# 1              5.519018
# ...

# %%
y.head()
# Out:
#    normalized_used_price
# 0               4.307572
# 1               5.162097
# 2               5.111084
# 3               5.135387
# 4               4.389995

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
x['device_brand']=label.fit_transform(x['device_brand'])
x['os']=label.fit_transform(x['os'])
x.head()
# Out:
#    device_brand  os  screen_size  4g  5g  rear_camera_mp  front_camera_mp  \
# 0            10   0        14.50   1   0            13.0              5.0
# 1            10   0        17.30   1   1            13.0             16.0
# 2            10   0        16.69   1   1            13.0              8.0
# 3            10   0        25.50   1   1            13.0              8.0
# 4            10   0        15.32   1   0            13.0              8.0
#
#    internal_memory  ram  battery  weight  release_year  days_used  \
# 0             64.0  3.0   3020.0   146.0          2020        127
# 1            128.0  8.0   4300.0   213.0          2020        325
# 2            128.0  8.0   4200.0   213.0          2020        162
# 3             64.0  6.0   7250.0   480.0          2020        345
# 4             64.0  3.0   5000.0   185.0          2020        293
#
#    normalized_new_price
# 0              4.715100
# 1              5.519018
# 2              5.884631
# ...

# %%
# x=pd.get_dummies(x,columns=['device_brand','os'],drop_first=True,dtype='int32')
# x.head()

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3422 entries, 0 to 3453
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   device_brand          3422 non-null   int32
#  1   os                    3422 non-null   int32
#  2   screen_size           3422 non-null   float64
#  3   4g                    3422 non-null   int64
#  4   5g                    3422 non-null   int64
#  5   rear_camera_mp        3422 non-null   float64
#  6   front_camera_mp       3422 non-null   float64
#  7   internal_memory       3422 non-null   float64
#  8   ram                   3422 non-null   float64
#  9   battery               3422 non-null   float64
#  10  weight                3422 non-null   float64
#  11  release_year          3422 non-null   int64
#  12  days_used             3422 non-null   int64
#  13  normalized_new_price  3422 non-null   float64
# dtypes: float64(8), int32(2), int64(4)
# ...

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
print(xtrain.shape)
print(ytrain.shape)
print(xtest.shape)
print(ytest.shape)
# Out:
# (2395, 14)
# (2395, 1)
# (1027, 14)
# (1027, 1)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
linear_model=LinearRegression()
linear_model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
lr_train_pred=linear_model.predict(xtrain)
lr_test_pred=linear_model.predict(xtest)
lr_train_score=linear_model.score(xtrain,ytrain)
lr_test_score=linear_model.score(xtest,ytest)
lr_mse=mean_squared_error(ytest,lr_test_pred)
lr_r2_score=r2_score(ytest,lr_test_pred)

# %%
print("train score:",lr_train_score)
print("test score:",lr_test_score)
print("MSE:",lr_mse)
print("R2 score",lr_r2_score)
# Out:
# train score: 0.8411921689402277
# test score: 0.837377273954816
# MSE: 0.05524443426133034
# R2 score 0.837377273954816

# %%
data_c=ytest.copy()
data_c["pred"]=lr_test_pred
data_c['residual']=data_c['normalized_used_price']-data_c["pred"]
data_c.head()
# Out:
#       normalized_used_price      pred  residual
# 803                4.584253  4.407959  0.176294
# 2012               4.911625  4.651441  0.260184
# 2102               3.532518  3.370396  0.162122
# 1065               4.360675  4.130611  0.230064
# 456                3.470723  4.034027 -0.563304

# %%
plt.figure(figsize=(10,7))
plt.scatter(data_c['pred'],data_c['residual'],color='red')
plt.title("Predicted vs Residual")
plt.xlabel("predicted")
plt.ylabel("residual")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
dtree_model=DecisionTreeRegressor()
dtree_model.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
dt_train_pred=dtree_model.predict(xtrain)
dt_test_pred=dtree_model.predict(xtest)
dt_train_score=dtree_model.score(xtrain,ytrain)
dt_test_score=dtree_model.score(xtest,ytest)
dt_mse=mean_squared_error(ytest,dt_test_pred)
dt_r2_score=r2_score(ytest,dt_test_pred)

# %%
print("train score:",dt_train_score)
print("test score:",dt_test_score)
print("MSE:",dt_mse)
print("R2 score:",dt_r2_score)
# Out:
# train score: 1.0
# test score: 0.7103679010347969
# MSE: 0.09839068524044171
# R2 score: 0.7103679010347969

# %%
data_c=ytest.copy()
data_c["pred"]=dt_test_pred
data_c['residual']=data_c['normalized_used_price']-data_c["pred"]
data_c.head()
# Out:
#       normalized_used_price      pred  residual
# 803                4.584253  4.374624  0.209629
# 2012               4.911625  4.560696  0.350929
# 2102               3.532518  4.167595 -0.635077
# 1065               4.360675  4.511958 -0.151282
# 456                3.470723  4.039360 -0.568637

# %%
plt.figure(figsize=(10,7))
plt.scatter(data_c['pred'],data_c['residual'],color='red')
plt.title("Predicted vs Residual")
plt.xlabel("predicted")
plt.ylabel("residual")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Decision Tree (hp)

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# %%
pipeline_dt=Pipeline([('reg',DecisionTreeRegressor())])
parameters={
    'reg__max_depth':(1,2,3,4,5),
    'reg__min_samples_split':(2,5,7)
}

# %%
import warnings
warnings.filterwarnings("ignore")
grid_search=GridSearchCV(pipeline_dt,parameters,scoring='r2')
grid_search.fit(xtrain,ytrain)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('reg', DecisionTreeRegressor())]),
#              param_grid={'reg__max_depth': (1, 2, 3, 4, 5),
#                          'reg__min_samples_split': (2, 5, 7)},
#              scoring='r2')

# %%
best_dt=grid_search.best_estimator_.get_params()
best_dt
# Out:
# {'memory': None,
#  'steps': [('reg', DecisionTreeRegressor(max_depth=5, min_samples_split=7))],
#  'verbose': False,
#  'reg': DecisionTreeRegressor(max_depth=5, min_samples_split=7),
#  'reg__ccp_alpha': 0.0,
#  'reg__criterion': 'squared_error',
#  'reg__max_depth': 5,
#  'reg__max_features': None,
#  'reg__max_leaf_nodes': None,
#  'reg__min_impurity_decrease': 0.0,
#  'reg__min_samples_leaf': 1,
#  'reg__min_samples_split': 7,
#  'reg__min_weight_fraction_leaf': 0.0,
#  'reg__random_state': None,
#  'reg__splitter': 'best'}

# %%
grid_search.best_score_
# Out:
# 0.787057133689421

# %%
dtree_hp_model=DecisionTreeRegressor(max_depth=5,min_samples_split=5,min_samples_leaf=1)
dtree_hp_model.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor(max_depth=5, min_samples_split=5)

# %%
dt_hp_train_pred=dtree_hp_model.predict(xtrain)
dt_hp_test_pred=dtree_hp_model.predict(xtest)
dt_hp_train_score=dtree_hp_model.score(xtrain,ytrain)
dt_hp_test_score=dtree_hp_model.score(xtest,ytest)
dt_hp_mse=mean_squared_error(ytest,dt_hp_test_pred)
dt_hp_r2_score=r2_score(ytest,dt_hp_test_pred)

# %%
print("train score:",dt_hp_train_score)
print("test score:",dt_hp_test_score)
print("MSE:",dt_hp_mse)
print("R2 score:",dt_hp_r2_score)
# Out:
# train score: 0.8405022231808671
# test score: 0.8031517309845774
# MSE: 0.06687116568232705
# R2 score: 0.8031517309845774

# %%
data_c=ytest.copy()
data_c["pred"]=dt_hp_test_pred
data_c['residual']=data_c['normalized_used_price']-data_c["pred"]
data_c.head()
# Out:
#       normalized_used_price      pred  residual
# 803                4.584253  4.413468  0.170785
# 2012               4.911625  4.626962  0.284663
# 2102               3.532518  3.345153  0.187365
# 1065               4.360675  4.096025  0.264651
# 456                3.470723  4.096025 -0.625301

# %%
plt.figure(figsize=(10,7))
plt.scatter(data_c['pred'],data_c['residual'],color='red')
plt.title("Predicted vs Residual")
plt.xlabel("predicted")
plt.ylabel("residual")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
ranfor_model=RandomForestRegressor()
ranfor_model.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor()

# %%
rf_train_pred=ranfor_model.predict(xtrain)
rf_test_pred=ranfor_model.predict(xtest)
rf_train_score=ranfor_model.score(xtrain,ytrain)
rf_test_score=ranfor_model.score(xtest,ytest)
rf_mse=mean_squared_error(ytest,rf_test_pred)
rf_r2_score=r2_score(ytest,rf_test_pred)

# %%
print("train score:",rf_train_score)
print("test score:",rf_test_score)
print("MSE:",rf_mse)
print("R2 score:",rf_r2_score)
# Out:
# train score: 0.9790140054076892
# test score: 0.8518441722601041
# MSE: 0.05032989598105464
# R2 score: 0.8518441722601041

# %%
data_c=ytest.copy()
data_c['pred']=rf_test_pred
data_c['res']=data_c['normalized_used_price']-data_c['pred']
data_c.head()
# Out:
#       normalized_used_price      pred       res
# 803                4.584253  4.448784  0.135469
# 2012               4.911625  4.635178  0.276447
# 2102               3.532518  3.589656 -0.057138
# 1065               4.360675  4.309595  0.051081
# 456                3.470723  4.054500 -0.583777

# %%
plt.figure(figsize=(10,7))
plt.scatter(data_c['pred'],data_c['res'],color='red')
plt.title("Predicted vs Residual")
plt.xlabel("predicted")
plt.ylabel("residual")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Random forest (hp)

# %%
pipeline_rf=Pipeline([('reg',RandomForestRegressor(random_state=42))])
parameters={
    'reg__max_depth':(2,5,10),
    'reg__min_samples_leaf':(1,2,4),
    'reg__min_samples_split':(2,5,10),
    'reg__n_estimators':(50,100,150),
}

# %%
grid_search=GridSearchCV(pipeline_rf,parameters,n_jobs=-1,scoring='r2')
grid_search.fit(xtrain,ytrain)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('reg',
#                                         RandomForestRegressor(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'reg__max_depth': (2, 5, 10),
#                          'reg__min_samples_leaf': (1, 2, 4),
#                          'reg__min_samples_split': (2, 5, 10),
#                          'reg__n_estimators': (50, 100, 150)},
#              scoring='r2')

# %%
grid_search.best_score_
# Out:
# 0.843960575236764

# %%
best_rf=grid_search.best_estimator_.get_params()
best_rf
# Out:
# {'memory': None,
#  'steps': [('reg',
#    RandomForestRegressor(max_depth=10, min_samples_leaf=2, min_samples_split=10,
#                          random_state=42))],
#  'verbose': False,
#  'reg': RandomForestRegressor(max_depth=10, min_samples_leaf=2, min_samples_split=10,
#                        random_state=42),
#  'reg__bootstrap': True,
#  'reg__ccp_alpha': 0.0,
#  'reg__criterion': 'squared_error',
#  'reg__max_depth': 10,
#  'reg__max_features': 1.0,
#  'reg__max_leaf_nodes': None,
#  'reg__max_samples': None,
#  'reg__min_impurity_decrease': 0.0,
#  'reg__min_samples_leaf': 2,
#  'reg__min_samples_split': 10,
#  'reg__min_weight_fraction_leaf': 0.0,
#  'reg__n_estimators': 100,
#  'reg__n_jobs': None,
#  'reg__oob_score': False,
#  'reg__random_state': 42,
#  'reg__verbose': 0,
#  'reg__warm_start': False}

# %%
ranfor_hp_model=RandomForestRegressor(max_depth=8,min_samples_split=5,min_samples_leaf=1,n_estimators=100)
ranfor_hp_model.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor(max_depth=8, min_samples_split=5)

# %%
rf_hp_train_pred=ranfor_hp_model.predict(xtrain)
rf_hp_test_pred=ranfor_hp_model.predict(xtest)
rf_hp_train_score=ranfor_hp_model.score(xtrain,ytrain)
rf_hp_test_score=ranfor_hp_model.score(xtest,ytest)
rf_hp_mse=mean_squared_error(ytest,rf_hp_test_pred)
rf_hp_r2_score=r2_score(ytest,rf_hp_test_pred)

# %%
print("train score:",rf_hp_train_score)
print("test score:",rf_hp_test_score)
print("MSE:",rf_hp_mse)
print("r2 score:",rf_hp_r2_score)
# Out:
# train score: 0.9195348589447128
# test score: 0.8552281182086008
# MSE: 0.04918033844969414
# r2 score: 0.8552281182086008

# %%
data_c=ytest.copy()
data_c["pred"]=rf_hp_test_pred
data_c['residual']=data_c['normalized_used_price']-data_c["pred"]
data_c.head()
# Out:
#       normalized_used_price      pred  residual
# 803                4.584253  4.427264  0.156989
# 2012               4.911625  4.633933  0.277692
# 2102               3.532518  3.521428  0.011090
# 1065               4.360675  4.186899  0.173777
# 456                3.470723  4.049389 -0.578666

# %%
plt.figure(figsize=(10,7))
plt.scatter(data_c['pred'],data_c['residual'],color='red')
plt.title("Predicted vs Residual")
plt.xlabel("predicted")
plt.ylabel("residual")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Adaboost

# %%
from sklearn.ensemble import AdaBoostRegressor
ada_model=AdaBoostRegressor(random_state=42)
ada_model.fit(xtrain,ytrain)
# Out:
# AdaBoostRegressor(random_state=42)

# %%
ad_train_pred=ada_model.predict(xtrain)
ad_test_pred=ada_model.predict(xtest)
ad_train_score=ada_model.score(xtrain,ytrain)
ad_test_score=ada_model.score(xtest,ytest)
ad_mse=mean_squared_error(ytest,ad_test_pred)
ad_r2_score=r2_score(ytest,ad_test_pred)

# %%
print("train score:",ad_train_score)
print("test score:",ad_test_score)
print("MSE:",ad_mse)
print("R2 score:",ad_r2_score)
# Out:
# train score: 0.8340566541572205
# test score: 0.8044447958865959
# MSE: 0.06643189965406389
# R2 score: 0.8044447958865959

# %%
data_c=ytest.copy()
data_c["pred"]=ad_test_pred
data_c['residual']=data_c['normalized_used_price']-data_c["pred"]
data_c.head()
# Out:
#       normalized_used_price      pred  residual
# 803                4.584253  4.561717  0.022536
# 2012               4.911625  4.648639  0.262986
# 2102               3.532518  3.555298 -0.022780
# 1065               4.360675  4.153262  0.207413
# 456                3.470723  4.060964 -0.590240

# %%
plt.figure(figsize=(10,7))
plt.scatter(data_c['pred'],data_c['residual'],color='red')
plt.title("Predicted vs Residual")
plt.xlabel("predicted")
plt.ylabel("residual")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Gradient boost

# %%
from sklearn.ensemble import GradientBoostingRegressor
gdb_model=GradientBoostingRegressor(random_state=42)
gdb_model.fit(xtrain,ytrain)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
gd_train_pred=gdb_model.predict(xtrain)
gd_test_pred=gdb_model.predict(xtest)
gd_train_score=gdb_model.score(xtrain,ytrain)
gd_test_score=gdb_model.score(xtest,ytest)
gd_mse=mean_squared_error(ytest,gd_test_pred)
gd_r2_score=r2_score(ytest,gd_test_pred)

# %%
print("train score:",gd_train_score)
print("test score:",gd_test_score)
print("MSE:",gd_mse)
print("R2 score:",gd_r2_score)
# Out:
# train score: 0.8946968272312678
# test score: 0.8539843062358308
# MSE: 0.04960287280534168
# R2 score: 0.8539843062358308

# %%
data_c=ytest.copy()
data_c["pred"]=gd_test_pred
data_c['residual']=data_c['normalized_used_price']-data_c["pred"]
data_c.head()
# Out:
#       normalized_used_price      pred  residual
# 803                4.584253  4.488982  0.095271
# 2012               4.911625  4.637028  0.274597
# 2102               3.532518  3.610339 -0.077821
# 1065               4.360675  4.158997  0.201679
# 456                3.470723  4.018528 -0.547805

# %%
plt.figure(figsize=(10,7))
plt.scatter(data_c['pred'],data_c['residual'],color='red')
plt.title("Predicted vs Residual")
plt.xlabel("predicted")
plt.ylabel("residual")
plt.grid(True)
plt.show()

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBRegressor
xgb_model=XGBRegressor()
xgb_model.fit(xtrain,ytrain)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
xg_train_pred=xgb_model.predict(xtrain)
xg_test_pred=xgb_model.predict(xtest)
xg_train_score=xgb_model.score(xtrain,ytrain)
xg_test_score=xgb_model.score(xtest,ytest)
xg_mse=mean_squared_error(ytest,xg_test_pred)
xg_r2_score=r2_score(ytest,xg_test_pred)

# %%
print("train score:",xg_train_score)
print("test score:",xg_test_score)
print("MSE",xg_mse)
print("R2 score:",xg_r2_score)
# Out:
# train score: 0.9882580205494045
# test score: 0.8320009729908078
# MSE 0.057070813097783675
# R2 score: 0.8320009729908078

# %%
data_c=ytest.copy()
data_c["pred"]=xg_test_pred
data_c['residual']=data_c['normalized_used_price']-data_c["pred"]
data_c.head()
# Out:
#       normalized_used_price      pred  residual
# 803                4.584253  4.419149  0.165104
# 2012               4.911625  4.534093  0.377532
# 2102               3.532518  3.707606 -0.175088
# 1065               4.360675  4.208496  0.152180
# 456                3.470723  3.778626 -0.307903

# %%
plt.figure(figsize=(10,7))
plt.scatter(data_c['pred'],data_c['residual'],color='red')
plt.title("Predicted vs Residual")
plt.xlabel("predicted")
plt.ylabel("residual")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ridge

# %%
from sklearn.linear_model import Ridge
rid_model=Ridge()
rid_para={'alpha':[0.5,1,2,3,4,5,10,20,30,40,50]}
rid_cv=GridSearchCV(rid_model,rid_para,cv=5,scoring='neg_mean_squared_error')
rid_cv.fit(xtrain,ytrain)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.5, 1, 2, 3, 4, 5, 10, 20, 30, 40, 50]},
#              scoring='neg_mean_squared_error')

# %%
print(rid_cv.best_params_['alpha'])
# Out:
# 3

# %%
ridge_model=Ridge(alpha=20)
ridge_model.fit(xtrain,ytrain)
# Out:
# Ridge(alpha=20)

# %%
rid_train_pred=ridge_model.predict(xtrain)
rid_test_pred=ridge_model.predict(xtest)
rid_train_score=ridge_model.score(xtrain,ytrain)
rid_test_score=ridge_model.score(xtest,ytest)
rid_mse=mean_squared_error(ytest,rid_test_pred)
rid_r2_score=r2_score(ytest,rid_test_pred)

# %%
print("train score:",rid_train_score)
print("test score:",rid_test_score)
print("MSE:",rid_mse)
print("R2 score:",rid_r2_score)
# Out:
# train score: 0.8409536243291338
# test score: 0.8380158640327222
# MSE: 0.05502749934431864
# R2 score: 0.8380158640327222

# %%
data_c=ytest.copy()
data_c["pred"]=rid_test_pred
data_c['residual']=data_c['normalized_used_price']-data_c["pred"]
data_c.head()
# Out:
#       normalized_used_price      pred  residual
# 803                4.584253  4.409676  0.174577
# 2012               4.911625  4.657453  0.254172
# 2102               3.532518  3.371116  0.161402
# 1065               4.360675  4.124972  0.235703
# 456                3.470723  4.027317 -0.556594

# %%
plt.figure(figsize=(10,7))
plt.scatter(data_c['pred'],data_c['residual'],color='red')
plt.title("Predicted vs Residual")
plt.xlabel("predicted")
plt.ylabel("residual")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Lasso

# %%
from sklearn.linear_model import Lasso
las_model=Lasso()
las_para={'alpha':[0.01,0.001,0.0001,0.5,1]}
las_cv=GridSearchCV(las_model,las_para,cv=5,scoring='neg_mean_squared_error')
las_cv.fit(xtrain,ytrain)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.001, 0.0001, 0.5, 1]},
#              scoring='neg_mean_squared_error')

# %%
las_cv.best_params_['alpha']
# Out:
# 0.0001

# %%
lasso_model=Lasso(alpha=0.001)
lasso_model.fit(xtrain,ytrain)
# Out:
# Lasso(alpha=0.001)

# %%
las_train_pred=lasso_model.predict(xtrain)
las_test_pred=lasso_model.predict(xtest)
las_train_score=lasso_model.score(xtrain,ytrain)
las_test_score=lasso_model.score(xtest,ytest)
las_mse=mean_squared_error(ytest,las_test_pred)
las_r2_score=r2_score(ytest,las_test_pred)

# %%
print("train score:",las_train_score)
print("test score:",las_test_score)
print("MSE:",las_mse)
print("R2 score:",las_r2_score)
# Out:
# train score: 0.8410091553007094
# test score: 0.8384539686102276
# MSE: 0.05487867119391079
# R2 score: 0.8384539686102276

# %%
data_c=ytest.copy()
data_c["pred"]=las_test_pred
data_c['residual']=data_c['normalized_used_price']-data_c["pred"]
data_c.head()
# Out:
#       normalized_used_price      pred  residual
# 803                4.584253  4.404538  0.179715
# 2012               4.911625  4.655384  0.256241
# 2102               3.532518  3.381635  0.150883
# 1065               4.360675  4.133928  0.226747
# 456                3.470723  4.035747 -0.565024

# %%
plt.figure(figsize=(10,7))
plt.scatter(data_c['pred'],data_c['residual'],color='red')
plt.title("Predicted vs Residual")
plt.xlabel("predicted")
plt.ylabel("residual")
plt.grid(True)
plt.show()

# %%
vals=[]
vals.append(['Linear Regression',lr_train_score,lr_test_score,lr_mse])
vals.append(['Decision Tree',dt_hp_train_score,dt_hp_test_score,dt_hp_mse])
vals.append(['Random Forest',rf_hp_train_score,rf_hp_test_score,rf_hp_mse])
vals.append(['Adaboost',ad_train_score,ad_test_score,ad_mse])
vals.append(['Gradient Boost',gd_train_score,gd_test_score,gd_mse])
vals.append(['XGBoost',xg_train_score,xg_test_score,xg_mse])
vals.append(['Ridge',rid_train_score,rid_test_score,rid_mse])
vals.append(['Lasso',las_train_score,las_test_score,las_mse])

# %%
best=pd.DataFrame(vals,columns=['Models','Train score','Test score','MSE'])
best
# Out:
#               Models  Train score  Test score       MSE
# 0  Linear Regression     0.841192    0.837377  0.055244
# 1      Decision Tree     0.840502    0.803152  0.066871
# 2      Random Forest     0.919535    0.855228  0.049180
# 3           Adaboost     0.834057    0.804445  0.066432
# 4     Gradient Boost     0.894697    0.853984  0.049603
# 5            XGBoost     0.988258    0.832001  0.057071
# 6              Ridge     0.840954    0.838016  0.055027
# 7              Lasso     0.841009    0.838454  0.054879

# %%
# from sklearn.model_selection import cross_val_score, KFold
# from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
# from sklearn.metrics import mean_squared_error
# import numpy as np

# # Define the models
# model1 = RandomForestRegressor()
# model2 = GradientBoostingRegressor()

# # Choose a cross-validation strategy (e.g., k-fold cross-validation)
# kf = KFold(n_splits=5, shuffle=True, random_state=42)

# # Perform cross-validation for model 1
# cv_scores_model1 = cross_val_score(model1, xtrain, ytrain, cv=kf, scoring='neg_mean_squared_error')
# mse_model1 = np.mean(-cv_scores_model1)  # Calculate mean squared error (convert neg_mean_squared_error to positive)

# # Perform cross-validation for model 2
# cv_scores_model2 = cross_val_score(model2, xtrain, ytrain, cv=kf, scoring='neg_mean_squared_error')
# mse_model2 = np.mean(-cv_scores_model2)  # Calculate mean squared error (convert neg_mean_squared_error to positive)

# # Compare the average performance metrics
# print("Mean Squared Error (Model 1):", mse_model1)
# print("Mean Squared Error (Model 2):", mse_model2)
# Out:
# Mean Squared Error (Model 1): 0.053748028586757604
# Mean Squared Error (Model 2): 0.0506129721880604

# %%
# from sklearn.model_selection import cross_val_score, KFold
# from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
# from sklearn.metrics import mean_squared_error
# import numpy as np

# # Define the models
# model1 = RandomForestRegressor()
# model2 = GradientBoostingRegressor()

# # Choose a cross-validation strategy (e.g., k-fold cross-validation)
# kf = KFold(n_splits=5, shuffle=True, random_state=42)

# # Perform cross-validation for model 1
# cv_scores_model1 = cross_val_score(model1, xtest, ytest, cv=kf, scoring='neg_mean_squared_error')
# mse_model1 = np.mean(-cv_scores_model1)  # Calculate mean squared error (convert neg_mean_squared_error to positive)

# # Perform cross-validation for model 2
# cv_scores_model2 = cross_val_score(model2, xtest, ytest, cv=kf, scoring='neg_mean_squared_error')
# mse_model2 = np.mean(-cv_scores_model2)  # Calculate mean squared error (convert neg_mean_squared_error to positive)

# # Compare the average performance metrics
# print("Mean Squared Error (Model 1):", mse_model1)
# print("Mean Squared Error (Model 2):", mse_model2)
# Out:
# Mean Squared Error (Model 1): 0.058252345087000945
# Mean Squared Error (Model 2): 0.05675114078532749

# %% [markdown]
# ### pickling model file for delpoyment

# %%
import pickle

# %%
pickle.dump(ranfor_hp_model,open('regmodel.pkl','wb'))

# %%
pickled_model=pickle.load(open('regmodel.pkl','rb'))

# %%
#prediction
pickled_model.predict(xtest)
# Out:
# array([4.42726438, 4.63393296, 3.52142828, ..., 4.05500017, 4.0197607 ,
#        4.90105786])
